# %% [markdown]
# <a href="https://colab.research.google.com/github/KOwaless/machine-learning/blob/main/02_linear/basic/01_linear_regression_normal_equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Importowanie bibliotek

# %%
import numpy as np

# %% [markdown]
# ###Przygotowanie danych

# %%
X1 = np.array([1, 2, 3, 4, 5, 6])
Y = np.array([3000, 3250, 3500, 3750, 4000, 4250])
m = len(X1)

print(f'Lata pracy: {X1}')
print(f'Wynagrodzenie: {Y}')
print(f'Liczba próbek: {m}')

# %%
X1 = X1.reshape(m, 1)
print(X1)
print(X1.shape)

# %%
bias = np.ones((m, 1))
print(bias)
print(bias.shape)

# %%
X = np.append(bias, X1, axis=1)
print(X)
print(X.shape)

# %% [markdown]
# ###Równanie normalne

# %%
np.dot(X.T, X)

# %%
L = np.linalg.inv(np.dot(X.T, X))
L

# %%
P = np.dot(X.T, Y)
P

# %%
np.dot(L, P)

# %% [markdown]
# ###Regresja liniowa przy pomocy scikit-learn

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()
regression.fit(X1, Y)

print(regression.intercept_)
print(regression.coef_[0])
# Out:
# 2750.0
# 250.0
